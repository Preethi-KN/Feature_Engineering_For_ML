# %%
import pandas as pd
from ydata_profiling import ProfileReport

df=pd.read_csv("worldcitiespop.csv")

#Padndas profiling --> output html file
prof=ProfileReport(df,title="Pandas Profiling of world Cities")

prof.to_file(output_file="WorldCities.html")


train_df=pd.read_csv("Train.csv")
prof=ProfileReport(train_df,title="Pandas Profiling of Train data")

prof.to_file(output_file="Train_data.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
