# %% [markdown]
# ### Standardization

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("Social_Network_Ads.csv")
df.head()
df=df.iloc[:,2:]
df.sample(5)
# Out:
#      Age  EstimatedSalary  Purchased
# 172   26           118000          0
# 229   42            80000          1
# 160   32           100000          1
# 37    30            49000          0
# 297   43           112000          1

# %% [markdown]
# #### Train test split

# %%
from sklearn.model_selection import train_test_split 
X_train,X_test,y_train,y_test=train_test_split(df.drop('Purchased',axis=1),df['Purchased'],test_size=0.3,random_state=0)

# %% [markdown]
# #### StandardScaler

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
#fit the scaler to the training data
scaler.fit(X_train)

#transfom train and test data
X_train_scaled=scaler.transform(X_train)
X_test_scaled=scaler.transform(X_test)

# %%
scaler.mean_
# Out:
# array([3.82571429e+01, 7.09714286e+04])

# %%
#as X_train_scaled is numpy we need to convert in to data frame
X_train_scaled=pd.DataFrame(X_train_scaled,columns=X_train.columns)
X_test_scaled=pd.DataFrame(X_test_scaled,columns=X_test.columns)
X_train_scaled
# Out:
#           Age  EstimatedSalary
# 0   -0.691857        -1.072986
# 1    1.977514         2.090415
# 2    0.928832         0.087895
# 3   -0.691857         0.523226
# 4   -0.024515        -0.347435
# ..        ...              ...
# 275  0.928832        -1.189074
# 276 -0.882527        -0.811788
# 277 -0.215184        -0.550589
# 278 -1.073196        -0.492545
# 279 -1.168531         1.364865
#
# [280 rows x 2 columns]

# %%
np.round(X_train_scaled.describe())
# Out:
#          Age  EstimatedSalary
# count  280.0            280.0
# mean    -0.0              0.0
# std      1.0              1.0
# min     -2.0             -2.0
# 25%     -1.0             -1.0
# 50%     -0.0              0.0
# 75%      1.0              1.0
# max      2.0              2.0

# %%
fig,(ax1,ax2)=plt.subplots(ncols=2,figsize=(12,5))
ax1.set_title("Before Scaling")
ax1.scatter(X_train['Age'],X_train['EstimatedSalary'])
ax2.set_title("After Scaling")
ax2.scatter(X_train_scaled['Age'],X_train_scaled['EstimatedSalary'],color='red')
plt.show()
#After scaling data is in between -1 to 1 mean 0

# %%
fig,(ax1,ax2)=plt.subplots(ncols=2,figsize=(15,7))
#before scaling
ax1.set_title("Before scaling")
sns.kdeplot(X_train['Age'],ax=ax1)
sns.kdeplot(X_train['EstimatedSalary'],ax=ax1)

#after scaling
ax2.set_title("After scaling")
sns.kdeplot(X_train_scaled['Age'],ax=ax2)
sns.kdeplot(X_train_scaled['EstimatedSalary'],ax=ax2)
plt.show()

# %% [markdown]
# #### Comparison of Distributions

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 5))

# before scaling
ax1.set_title('Salary Distribution Before Scaling')
sns.kdeplot(X_train['EstimatedSalary'], ax=ax1)

# after scaling
ax2.set_title('Salary Distribution Standard Scaling')
sns.kdeplot(X_train_scaled['EstimatedSalary'], ax=ax2)
plt.show()

# %% [markdown]
# #### Why scaling is important?

# %%
from sklearn.linear_model import LogisticRegression

# %%
# lets check for scaled and not scaled data for model
lr = LogisticRegression()
lr_scaled = LogisticRegression()

# %%
lr.fit(X_train,y_train)
lr_scaled.fit(X_train_scaled,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = lr.predict(X_test)
y_pred_scaled = lr_scaled.predict(X_test_scaled)

# %%
from sklearn.metrics import accuracy_score

# %%
print("Actual",accuracy_score(y_test,y_pred))
print("Scaled",accuracy_score(y_test,y_pred_scaled))
# Out:
# Actual 0.8677685950413223
# Scaled 0.8677685950413223
